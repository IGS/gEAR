# %%
###

# gEAR Notebook Starter (Python / Scanpy)

Welcome! This notebook is connected to datasets from the gEAR portal.

# What you should know

- Your dataset(s) are mounted at: `/data/`
- You **cannot modify the original dataset files** (read-only)
- You should save results to your home directory: `/home/nbuser/`

# Important: Large dataset handling

Many gEAR datasets are large (GB-scale). To avoid running out of memory:

- Use **backed mode** when loading data
- Subset before converting to in-memory objects
- Avoid converting full matrices to dense arrays

# What to do now? Get started with Scanpy tutorials for examples:
#  https://scanpy.readthedocs.io/en/stable/tutorials/index.html

###

import os
import numpy as np
import pandas as pd
import scanpy as sc

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80, facecolor='white')

selected_dataset = os.environ.get("GEAR_SELECTED_DATASET", "")
h5_path = f"/data/{selected_dataset}"

adata = sc.read_h5ad(h5_path, backed="r")
