# %% [markdown]
# # gEAR Analysis Notebook
#
# This notebook lets you explore your dataset using Python and Scanpy.
#
# Your selected dataset is mounted and ready for use.
#
# For documentation and examples of analyses you can do, see this link:
#
# https://scanpy.readthedocs.io/en/stable/tutorials/index.html

# %%
import os

selected_dataset = os.environ.get("GEAR_SELECTED_DATASET")
print("Selected dataset:", selected_dataset)

import scanpy as sc

if not selected_dataset:
    raise ValueError("No dataset selected")

path = f"/data/{selected_dataset}"
print(f"Loading {path}")

adata = sc.read_h5ad(path)

adata
# Out:
# Selected dataset: None
